# %% [markdown]
# # Data Visualization Matchmaker
#
# ### Supplying a dataset's contextual description
#
# All of the celestial bodies that revolve around the Sun are collectively referred to as the Solar System. Some 4.6 billion years ago, it was born when a massive interstellar molecular cloud disintegrated under the force of gravity. The Sun still accounts for almost all of the mass in the solar system (98.18 percent), but Jupiter possesses most of the rest. Mercury, Venus, Earth, and Mars are all considered terrestrial planets since they are mostly composed of rock and metal. In addition to Earth, there are three more massive planets in the solar system. The two largest planets, Jupiter and Saturn, are known as gas giants because they are made up mostly of hydrogen and helium; the next two largest planets, Uranus and Neptune, are known as ice giants because they are made up mostly of volatile substances with relatively high melting points compared to hydrogen and helium, such as water, ammonia, and methane. All eight planets move in nearly circular paths that cross the ecliptic plane or go in the opposite direction.
#
# ### Content
#
# This data set includes astronomical observations from eight of the planets in our solar system. Some of the characteristics of the eight planets in our solar system included in this data set include name, color, mass, diameter, density, gravity, escape velocity, rotation period, day length, distance from the sun, perihelion, aphelion, orbital period, orbital velocity, orbital inclination, orbital eccentricity, obliquity to orbit, mean temperature, surface pressure, number of moons, ring system, and global magnetic field.
#
# Source: https://www.kaggle.com/datasets/iamsouravbanerjee/planet-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load a dataset into a DataFrame 
df = pd.read_csv("planets.csv")

# Print the number of rows and columns 
print("Number of rows and columns:", df.shape)

# Print out the first five rows 
df.head()
# Out:
# Number of rows and columns: (8, 22)
#     Planet                                            Color  Mass (10^24kg)  \
# 0  Mercury                                             Grey           0.330
# 1    Venus                                   Brown and Grey           4.870
# 2    Earth                      Blue, Brown Green and White           5.970
# 3     Mars                               Red, Brown and Tan           0.642
# 4  Jupiter  Brown, Orange and Tan, with White cloud stripes        1898.000
#
#    Diameter (km)  Density (kg/m^3)  Surface Gravity(m/s^2)  \
# 0           4879              5429                     3.7
# 1          12104              5243                     8.9
# 2          12756              5514                     9.8
# 3           6792              3934                     3.7
# 4         142984              1326                    23.1
#
#    Escape Velocity (km/s)  Rotation Period (hours)  Length of Day (hours)  \
# ...

# %% [markdown]
# Only eight rows and twenty-two columns are available in the dataset. Each of the eight rows represents one of the eight planets in our solar system. Each of the planets is described in 22 separate columns.

# %% [markdown]
# ## Understanding columns and rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Planet                         8 non-null      object
#  1   Color                          8 non-null      object
#  2   Mass (10^24kg)                 8 non-null      float64
#  3   Diameter (km)                  8 non-null      int64
#  4   Density (kg/m^3)               8 non-null      int64
#  5   Surface Gravity(m/s^2)         8 non-null      float64
#  6   Escape Velocity (km/s)         8 non-null      float64
#  7   Rotation Period (hours)        8 non-null      float64
#  8   Length of Day (hours)          8 non-null      float64
#  9   Distance from Sun (10^6 km)    8 non-null      float64
#  10  Perihelion (10^6 km)           8 non-null      float64
#  11  Aphelion (10^6 km)             8 non-null      float64
# ...

# %% [markdown]
# The "float64" data type predominates, followed by "object" (six instances) and "int64" (four instances). Only six of the columns are qualitative, distinct, and categorical, while the other 15 deal with quantitative information.

# %%
df.isna().sum()
# Out:
# Planet                           0
# Color                            0
# Mass (10^24kg)                   0
# Diameter (km)                    0
# Density (kg/m^3)                 0
# Surface Gravity(m/s^2)           0
# Escape Velocity (km/s)           0
# Rotation Period (hours)          0
# Length of Day (hours)            0
# Distance from Sun (10^6 km)      0
# Perihelion (10^6 km)             0
# Aphelion (10^6 km)               0
# Orbital Period (days)            0
# Orbital Velocity (km/s)          0
# Orbital Inclination (degrees)    0
# Orbital Eccentricity             0
# Obliquity to Orbit (degrees)     0
# Mean Temperature (C)             0
# Surface Pressure (bars)          0
# Number of Moons                  0
# Ring System?                     0
# Global Magnetic Field?           0
# dtype: int64

# %% [markdown]
# Since there are no missing or invalid values in the dataset, data visualizations may be made without first doing any data cleaning.

# %%
df.describe()
# Out:
#        Mass (10^24kg)  Diameter (km)  Density (kg/m^3)  \
# count        8.000000       8.000000          8.000000
# mean       333.326500   50087.125000       3130.125000
# std        660.538057   53916.366175       2104.022368
# min          0.330000    4879.000000        687.000000
# 25%          3.813000   10776.000000       1312.000000
# 50%         46.385000   31142.000000       2786.000000
# 75%        218.500000   68472.500000       5289.500000
# max       1898.000000  142984.000000       5514.000000
#
#        Surface Gravity(m/s^2)  Escape Velocity (km/s)  \
# count                8.000000                 8.00000
# mean                 9.737500                21.33750
# std                  6.040089                18.67473
# min                  3.700000                 4.30000
# 25%                  7.450000                 9.05000
# 50%                  8.950000                16.25000
# 75%                 10.100000                26.50000
# ...

# %% [markdown]
# Each numerical column may be given useful descriptive statistics thanks to the describe() method. Its output displays the percentile rank, mean, standard deviation, minimum, and maximum values.
#
# It is time to print the unique values from the object columns using the unique() method and the number of rows for each unique value using the value counts() function.

# %%
df["Planet"].unique()
# Out:
# array(['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus',
#        'Neptune'], dtype=object)

# %%
df["Planet"].value_counts()
# Out:
# Mercury    1
# Venus      1
# Earth      1
# Mars       1
# Jupiter    1
# Saturn     1
# Uranus     1
# Neptune    1
# Name: Planet, dtype: int64

# %%
df["Color"].unique()
# Out:
# array(['Grey', 'Brown and Grey', 'Blue, Brown Green and White',
#        'Red, Brown and Tan',
#        'Brown, Orange and Tan, with White cloud stripes',
#        'Golden, Brown, and Blue-Grey', 'Blue-Green', 'Blue'], dtype=object)

# %%
df["Color"].value_counts()
# Out:
# Grey                                               1
# Brown and Grey                                     1
# Blue, Brown Green and White                        1
# Red, Brown and Tan                                 1
# Brown, Orange and Tan, with White cloud stripes    1
# Golden, Brown, and Blue-Grey                       1
# Blue-Green                                         1
# Blue                                               1
# Name: Color, dtype: int64

# %%
df["Orbital Period (days)"].unique()
# Out:
# array(['88', '224.7', '365.2', '687', '4331', '10,747', '30,589',
#        '59,800'], dtype=object)

# %%
df["Orbital Period (days)"].value_counts()
# Out:
# 88        1
# 224.7     1
# 365.2     1
# 687       1
# 4331      1
# 10,747    1
# 30,589    1
# 59,800    1
# Name: Orbital Period (days), dtype: int64

# %%
df["Surface Pressure (bars)"].unique()
# Out:
# array(['0', '92', '1', '0.01', 'Unknown'], dtype=object)

# %%
df["Surface Pressure (bars)"].value_counts()
# Out:
# Unknown    4
# 0          1
# 92         1
# 1          1
# 0.01       1
# Name: Surface Pressure (bars), dtype: int64

# %%
df["Ring System?"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Ring System?"].value_counts()
# Out:
# No     4
# Yes    4
# Name: Ring System?, dtype: int64

# %%
df["Global Magnetic Field?"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Global Magnetic Field?"].value_counts()
# Out:
# Yes    6
# No     2
# Name: Global Magnetic Field?, dtype: int64

# %% [markdown]
# ## Basic visualizations

# %% [markdown]
# ### Bar graph

# %%
df.plot(kind="bar",
       x="Planet",
       y="Diameter (km)")
plt.title("Planet diameter")
plt.show()

# %% [markdown]
# That is a bar chart, by the way. The planets were shown along the x-axis, while the y-axis was the diameter in kilometers. For this purpose, the color blue works well since it allows us to clearly discern the planets and their diameters in kilometers.
#
# Bar graph showing the relative diameters of the planets, with Jupiter on top, Saturn in second place, and Uranus in third place, in terms of kilometers. When compared to Neptune, Uranus is much larger in diameter. The diameter of Mercury is the smallest of the planets, followed by Mars and Venus.
#
# In terms of planet size, Earth and Neptune are somewhat in the middle.
#
# I believe a rectangular form would work best for the markers in the bar graph to indicate these planetary characteristics. Because of this, determining the planetary diameters is much less of a guessing game.

# %% [markdown]
# ### Scatter plot

# %%
df.plot(kind="scatter",
       x="Diameter (km)",
       y="Mean Temperature (C)")
plt.title("Mean temperature vs. diameter")
plt.show()

# %% [markdown]
# This graphic represents a scatter plot. I opted for this chart instead of a line graph to demonstrate the correlation between mean temperature in C and diameter in kilometers. The x-axis represents the mean temperature in degrees Celsius, while the y-axis represents the diameter of the planets in kilometers.
#
# The scatter plot suggests that there is no relationship between the two factors. Nonetheless, the fact that smaller planets tend to be hotter than bigger ones is an intriguing observation. I am not an astronomer, but this helps explain why Earth is so large relative to other planets by considering their average temperatures. If this is right, then Jupiter must be the coldest planet in the solar system.
#
# As for the symbols used in the scatter plot, circles work well for representing the points that stand for the average temperatures in degrees Celsius and the planetary sizes in kilometers. The scatter graph is more legible.
